# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
# function to plot heatmap for 15 trees with their changed trees
def plot_heatmap(df_list, trees, title = ''):
    fig, ax = plt.subplots(5, 3, figsize=(18, 16))
    for i in range(0,15):
        plot = sns.heatmap(df_list[i], annot=True, cmap="crest",vmin = 0, vmax = 1, 
                           ax=ax[math.floor(i/3), i - 3*math.floor(i/3)], cbar = False);
        plot.xaxis.tick_top()
        plot.set_title(trees[i])
        plot.tick_params(axis='y', rotation=0)
    fig.suptitle(title, fontsize='xx-large')
    plt.tight_layout()

# %%
trees = ["(((4,3),2),1)","(((4,2),3),1)","(((3,2),4),1)","(((4,3),1),2)","(((4,1),3),2)",
         "(((1,3),4),2)","(((1,2),4),3)","(((4,2),1),3)","(((4,1),2),3)","(((2,1),3),4)",
         "(((1,3),2),4)","(((3,2),1),4)","((4,3),(2,1))","((4,1),(2,3))","((4,2),(3,1))"]

# %%
df = pd.read_csv("./data/kmeans_4taxa_100.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('100 trees K-means')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_prob_4taxa_100.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('100 trees GMM posterior probability')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_llpg_4taxa_100.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('100 trees GMM log likelihood')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/kmeans_4taxa_1000.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('1000 trees K-means')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_prob_4taxa_1000.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('1000 trees GMM posterior probability')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_llpg_4taxa_1000.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('1000 trees GMM log likelihood')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/kmeans_4taxa_5000.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('5000 trees K-means')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_prob_4taxa_5000.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('5000 trees GMM posterior probability')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_llpg_4taxa_5000.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('5000 trees GMM log likelihood')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
change = ["org","inc","inc_r","dec","dec_r","all_r"]
dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/kmeans_4_tree_" + str(i) + "_100.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'100 trees K-means')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_prob_4_tree_" + str(i) + "_100.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'100 trees GMM posterior probability')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_llpg_4_tree_" + str(i) + "_100.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'100 trees GMM log likelihood')

# %%
change = ["org","inc","inc_r","dec","dec_r","all_r"]
dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/kmeans_4_tree_" + str(i) + "_1000.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'1000 trees K-means')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_prob_4_tree_" + str(i) + "_1000.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'1000 trees GMM posterior probability')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_llpg_4_tree_" + str(i) + "_1000.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'1000 trees GMM log likelihood')

# %%
change = ["org","inc","inc_r","dec","dec_r","all_r"]
dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/kmeans_4_tree_" + str(i) + "_5000.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'5000 trees K-means')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_prob_4_tree_" + str(i) + "_5000.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'5000 trees GMM posterior probability')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_llpg_4_tree_" + str(i) + "_5000.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees, '5000 trees GMM log likelihood')

# %%
from itertools import combinations

result_kmeans = pd.read_csv("./data/kmeans_4taxa_5000.csv")
result_kmeans = result_kmeans.to_numpy()
result_GMM = pd.read_csv("./data/GMM_prob_4taxa_5000.csv")
result_GMM = result_GMM.to_numpy()
all_comb = list(combinations(range(0,15),2))
good_kmeans = []
good_GMM = []
good_both = []
bad_both = []
for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    if result_GMM[i,j] > 0.7 and result_kmeans[i,j]>0.7:
        good_both.append(pair)
        good_kmeans.append(pair)
        good_GMM.append(pair)
    elif result_kmeans[i,j] > 0.7:
        good_kmeans.append(pair)
    elif result_GMM[i,j] > 0.7:
        good_GMM.append(pair)
    else:
        bad_both.append(pair)

# %%
print("Both good: ", good_both)
print("Kmeans good: ", good_kmeans)
print("GMM good: ", good_GMM)
print("Both bad: ", bad_both)
# Out:
# Both good:  [(1, 5), (3, 6), (3, 7), (3, 8), (3, 10), (4, 11), (5, 8), (5, 13), (6, 7), (6, 10), (7, 12), (8, 12), (9, 11), (9, 15)]
# Kmeans good:  [(1, 5), (1, 9), (2, 10), (2, 14), (3, 6), (3, 7), (3, 8), (3, 10), (4, 11), (4, 14), (5, 8), (5, 10), (5, 11), (5, 13), (6, 7), (6, 9), (6, 10), (7, 12), (8, 12), (9, 11), (9, 13), (9, 15), (10, 14), (11, 13), (12, 13), (14, 15)]
# GMM good:  [(1, 5), (1, 6), (1, 8), (1, 11), (1, 12), (2, 3), (2, 4), (2, 5), (2, 7), (2, 9), (2, 12), (3, 4), (3, 6), (3, 7), (3, 8), (3, 10), (4, 6), (4, 9), (4, 11), (4, 12), (5, 8), (5, 13), (5, 15), (6, 7), (6, 10), (6, 13), (7, 9), (7, 11), (7, 12), (8, 10), (8, 12), (9, 10), (9, 11), (9, 15), (10, 11), (10, 12), (12, 15)]
# Both bad:  [(1, 2), (1, 3), (1, 4), (1, 7), (1, 10), (1, 13), (1, 14), (1, 15), (2, 6), (2, 8), (2, 11), (2, 13), (2, 15), (3, 5), (3, 9), (3, 11), (3, 12), (3, 13), (3, 14), (3, 15), (4, 5), (4, 7), (4, 8), (4, 10), (4, 13), (4, 15), (5, 6), (5, 7), (5, 9), (5, 12), (5, 14), (6, 8), (6, 11), (6, 12), (6, 14), (6, 15), (7, 8), (7, 10), (7, 13), (7, 14), (7, 15), (8, 9), (8, 11), (8, 13), (8, 14), (8, 15), (9, 12), (9, 14), (10, 13), (10, 15), (11, 12), (11, 14), (11, 15), (12, 14), (13, 14), (13, 15)]

# %%
matrix = [[0 for x in range(15)] for y in range(15)] 

for pair in good_kmeans:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 1
    matrix[j][i] += 1

for pair in good_GMM:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 2
    matrix[j][i] += 2
    
matrix = pd.DataFrame(matrix)
matrix.columns += 1
matrix.index += 1

plt.figure(figsize=(12,12))
plt.title('Good performance = 0.7')
plot = sns.heatmap(matrix, annot=True, cmap="crest", cbar = False)
plt.legend(['Bad','K-means','GMM','Both']);

# %%
good_kmeans = []
good_GMM = []
good_both = []
bad_both = []
for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    if result_GMM[i,j] > 0.83 and result_kmeans[i,j]>0.7:
        good_both.append(pair)
        good_kmeans.append(pair)
        good_GMM.append(pair)
    elif result_kmeans[i,j] > 0.83:
        good_kmeans.append(pair)
    elif result_GMM[i,j] > 0.83:
        good_GMM.append(pair)
    else:
        bad_both.append(pair)

# %%
matrix = [[0 for x in range(15)] for y in range(15)] 

for pair in good_kmeans:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 1
    matrix[j][i] += 1

for pair in good_GMM:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 2
    matrix[j][i] += 2
    
matrix = pd.DataFrame(matrix)
matrix.columns += 1
matrix.index += 1

plt.figure(figsize=(12,12))
plt.title('Good performance = 0.9')
plot = sns.heatmap(matrix, annot=True, cmap="crest", cbar = False)
plt.legend(['Bad','K-means','GMM','Both']);
