# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
# function to plot heatmap for 15 trees with their changed trees
def plot_heatmap(df_list, trees, title = ''):
    fig, ax = plt.subplots(5, 3, figsize=(18, 16))
    for i in range(0,15):
        plot = sns.heatmap(df_list[i], annot=True, cmap="crest",vmin = 0, vmax = 1, 
                           ax=ax[math.floor(i/3), i - 3*math.floor(i/3)], cbar = False);
        plot.xaxis.tick_top()
        plot.set_title(trees[i])
        plot.tick_params(axis='y', rotation=0)
    fig.suptitle(title, fontsize='xx-large')
    plt.tight_layout()

# %%
trees = ["(((4,3),2),1)","(((4,2),3),1)","(((3,2),4),1)","(((4,3),1),2)","(((4,1),3),2)",
         "(((1,3),4),2)","(((1,2),4),3)","(((4,2),1),3)","(((4,1),2),3)","(((2,1),3),4)",
         "(((1,3),2),4)","(((3,2),1),4)","((4,3),(2,1))","((4,1),(2,3))","((4,2),(3,1))"]

# %%
df = pd.read_csv("./data/kmeans_4taxa_100.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('100 trees K-means')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_prob_4taxa_100.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('100 trees GMM posterior probability')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_llpg_4taxa_100.csv")
df.columns = trees
df.index = trees

plt.figure(figsize=(12,12))
plt.title('100 trees GMM log likelihood')
plot = sns.heatmap(df, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/kmeans_4taxa_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/kmeans_4taxa_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
kmeans_1000 = pd.DataFrame(accuracy)
kmeans_1000.columns = trees
kmeans_1000.index = trees

plt.figure(figsize=(12,12))
plt.title('1000 trees K-means')
plot = sns.heatmap(kmeans_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)


df = pd.read_csv("./data/GMM_prob_4taxa_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/GMM_prob_4taxa_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
prob_1000 = pd.DataFrame(accuracy)
prob_1000.columns = trees
prob_1000.index = trees

plt.figure(figsize=(12,12))
plt.title('1000 trees GMM posterior probability')
plot = sns.heatmap(prob_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_llpg_4taxa_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/GMM_llpg_4taxa_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
llpg_1000 = pd.DataFrame(accuracy)
llpg_1000.columns = trees
llpg_1000.index = trees

plt.figure(figsize=(12,12))
plt.title('1000 trees GMM log likelihood')
plot = sns.heatmap(llpg_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/kmeans_4taxa_5000_1.csv")
accuracy = df.values
for i in range(19):
    path = "./data/kmeans_4taxa_5000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 20
kmeans_5000 = pd.DataFrame(accuracy)
kmeans_5000.columns = trees
kmeans_5000.index = trees

plt.figure(figsize=(12,12))
plt.title('5000 trees K-means')
plot = sns.heatmap(kmeans_5000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)



df = pd.read_csv("./data/GMM_prob_4taxa_5000_1.csv")
accuracy = df.values
for i in range(19):
    path = "./data/GMM_prob_4taxa_5000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 20
prob_5000 = pd.DataFrame(accuracy)
prob_5000.columns = trees
prob_5000.index = trees

plt.figure(figsize=(12,12))
plt.title('5000 trees GMM posterior probability')
plot = sns.heatmap(prob_5000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)



df = pd.read_csv("./data/GMM_llpg_4taxa_5000_1.csv")
accuracy = df.values
for i in range(19):
    path = "./data/GMM_llpg_4taxa_5000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 20
llpg_5000 = pd.DataFrame(accuracy)
llpg_5000.columns = trees
llpg_5000.index = trees

plt.figure(figsize=(12,12))
plt.title('llpg_5000 trees GMM log likelihood')
plot = sns.heatmap(llpg_5000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
change = ["org","inc","inc_r","dec","dec_r","all_r"]
dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/kmeans_4_tree_" + str(i) + "_100.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'100 trees K-means')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_prob_4_tree_" + str(i) + "_100.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'100 trees GMM posterior probability')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_llpg_4_tree_" + str(i) + "_100.csv")
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'100 trees GMM log likelihood')

# %%
change = ["org","inc","inc_r","dec","dec_r","all_r"]
dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/kmeans_4_tree_" + str(i) + "_1000_1.csv")
    accuracy = df.values
    for j in range(99):
        path = "./data/kmeans_4_tree_" + str(i) + "_1000_" + str(j + 2) + ".csv"
        df = pd.read_csv(path)
        accuracy += df.values
        
    accuracy /= 100
    df = pd.DataFrame(accuracy)
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'1000 trees K-means')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_prob_4_tree_" + str(i) + "_1000_1.csv")
    accuracy = df.values
    for j in range(99):
        path = "./data/GMM_prob_4_tree_" + str(i) + "_1000_" + str(j + 2) + ".csv"
        df = pd.read_csv(path)
        accuracy += df.values
    
    accuracy /= 100
    df = pd.DataFrame(accuracy)
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'1000 trees GMM posterior probability')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_llpg_4_tree_" + str(i) + "_1000_1.csv")
    accuracy = df.values
    for j in range(99):
        path = "./data/GMM_llpg_4_tree_" + str(i) + "_1000_" + str(j + 2) + ".csv"
        df = pd.read_csv(path)
        accuracy += df.values
    
    accuracy /= 100
    df = pd.DataFrame(accuracy)
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'1000 trees GMM log likelihood')

# %%
change = ["org","inc","inc_r","dec","dec_r","all_r"]
dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/kmeans_4_tree_" + str(i) + "_5000_1.csv")
    accuracy = df.values
    for j in range(19):
        path = "./data/kmeans_4_tree_" + str(i) + "_5000_" + str(j + 2) + ".csv"
        df = pd.read_csv(path)
        accuracy += df.values
        
    accuracy /= 20
    df = pd.DataFrame(accuracy)
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'5000 trees K-means')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_prob_4_tree_" + str(i) + "_5000_1.csv")
    accuracy = df.values
    for j in range(19):
        path = "./data/GMM_prob_4_tree_" + str(i) + "_5000_" + str(j + 2) + ".csv"
        df = pd.read_csv(path)
        accuracy += df.values
    
    accuracy /= 20
    df = pd.DataFrame(accuracy)
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'5000 trees GMM posterior probability')

dfs = []
for i in range(1,16):
    df = pd.read_csv("./data/GMM_llpg_4_tree_" + str(i) + "_5000_1.csv")
    accuracy = df.values
    for j in range(19):
        path = "./data/GMM_llpg_4_tree_" + str(i) + "_5000_" + str(j + 2) + ".csv"
        df = pd.read_csv(path)
        accuracy += df.values
    
    accuracy /= 20
    df = pd.DataFrame(accuracy)
    df.columns = change
    df.index = change
    dfs.append(df)
    
plot_heatmap(dfs,trees,'5000 trees GMM log likelihood')

# %%
unrooted = ["1: 12|34","2: 13|24","3: 14|23","4: 12|34","5: 14|23",
            "6: 13|24","7: 12|34","8: 13|24","9: 14|23","10: 12|34",
            "11: 13|24","12: 14|23","13: 12|34","14: 14|23","15: 13|24"]
newIdx = ["1: 12|34", "4: 12|34", "7: 12|34", "10: 12|34", "13: 12|34", 
          "2: 13|24", "6: 13|24", "8: 13|24", "11: 13|24", "15: 13|24", 
          "3: 14|23", "5: 14|23", "9: 14|23", "12: 14|23", "14: 14|23"]

# %%
# 1000 trees


from itertools import combinations

result_kmeans = kmeans_1000.to_numpy()
result_GMM = prob_1000.to_numpy()
all_comb = list(combinations(range(0,15),2))
good_kmeans = []
good_GMM = []
good_both = []
bad_both = []
for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    if result_GMM[i,j] >= 0.68 and result_kmeans[i,j] >= 0.68:
        good_both.append(pair)
        good_kmeans.append(pair)
        good_GMM.append(pair)
    elif result_kmeans[i,j] >= 0.68:
        good_kmeans.append(pair)
    elif result_GMM[i,j] >= 0.68:
        good_GMM.append(pair)
    else:
        bad_both.append(pair)

# %%
matrix = [[0 for x in range(15)] for y in range(15)] 

for pair in good_kmeans:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 1
    matrix[j][i] += 1

for pair in good_GMM:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 2
    matrix[j][i] += 2
    
matrix = pd.DataFrame(matrix)
matrix.columns = unrooted
matrix.index = unrooted
matrix = matrix.reindex(newIdx)
matrix = matrix.reindex(columns = newIdx)

plt.figure(figsize=(12,12))
plt.title('Good performance = 0.68')
plot = sns.heatmap(matrix, annot=True, cmap="crest", cbar = False)
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
# 5000 trees


result_kmeans = kmeans_5000.to_numpy()
result_GMM = prob_5000.to_numpy()
all_comb = list(combinations(range(0,15),2))
good_kmeans = []
good_GMM = []
good_both = []
bad_both = []
for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    if result_GMM[i,j] >= 0.68 and result_kmeans[i,j] >= 0.68:
        good_both.append(pair)
        good_kmeans.append(pair)
        good_GMM.append(pair)
    elif result_kmeans[i,j] >= 0.68:
        good_kmeans.append(pair)
    elif result_GMM[i,j] >= 0.68:
        good_GMM.append(pair)
    else:
        bad_both.append(pair)

# %%
matrix = [[0 for x in range(15)] for y in range(15)] 

for pair in good_kmeans:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 1
    matrix[j][i] += 1

for pair in good_GMM:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 2
    matrix[j][i] += 2
    
matrix = pd.DataFrame(matrix)
matrix.columns = unrooted
matrix.index = unrooted
matrix = matrix.reindex(newIdx)
matrix = matrix.reindex(columns = newIdx)

plt.figure(figsize=(12,12))
plt.title('Good performance = 0.68')
plot = sns.heatmap(matrix, annot=True, cmap="crest", cbar = False)
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
# different topologies

df = pd.read_csv("./data/kmeans_4_diff_topo_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/kmeans_4_diff_topo_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
diff_kmeans_1000 = pd.DataFrame(accuracy)
diff_kmeans_1000.columns = trees
diff_kmeans_1000.index = trees

plt.figure(figsize=(12,12))
plt.title('1000 different topologies K-means')
plot = sns.heatmap(diff_kmeans_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_prob_4_topo_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/GMM_prob_4_topo_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
diff_prob_1000 = pd.DataFrame(accuracy)
diff_prob_1000.columns = trees
diff_prob_1000.index = trees

plt.figure(figsize=(12,12))
plt.title('1000 different topologies GMM prob')
plot = sns.heatmap(diff_prob_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_llpg_4_topo_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/GMM_llpg_4_topo_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
diff_llpg_1000 = pd.DataFrame(accuracy)
diff_llpg_1000.columns = trees
diff_llpg_1000.index = trees

plt.figure(figsize=(12,12))
plt.title('1000 different topologies GMM llpg')
plot = sns.heatmap(diff_llpg_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
result_kmeans = diff_kmeans_1000.to_numpy()
result_GMM = diff_prob_1000.to_numpy()
all_comb = list(combinations(range(0,15),2))
good_kmeans = []
good_GMM = []
good_both = []
bad_both = []
for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    if result_GMM[i,j] >= 0.7 and result_kmeans[i,j] >= 0.7:
        good_both.append(pair)
        good_kmeans.append(pair)
        good_GMM.append(pair)
    elif result_kmeans[i,j] >= 0.7:
        good_kmeans.append(pair)
    elif result_GMM[i,j] >= 0.7:
        good_GMM.append(pair)
    else:
        bad_both.append(pair)

# %%
matrix = [[0 for x in range(15)] for y in range(15)] 

for pair in good_kmeans:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 1
    matrix[j][i] += 1

for pair in good_GMM:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix[i][j] += 2
    matrix[j][i] += 2
    
matrix = pd.DataFrame(matrix)
matrix.columns = unrooted
matrix.index = unrooted
matrix = matrix.reindex(newIdx)
matrix = matrix.reindex(columns = newIdx)

matix = matrix[["1: 12|34", "4: 12|34", "7: 12|34", "10: 12|34", "13: 12|34", 
                "2: 13|24", "6: 13|24", "8: 13|24", "11: 13|24", "15: 13|24", 
                "3: 14|23", "5: 14|23", "9: 14|23", "12: 14|23", "14: 14|23"]]

plt.figure(figsize=(12,12))
plt.title('Good performance = 0.7')
plot = sns.heatmap(matrix, annot=True, cmap="crest", cbar = False)
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
# different topologies for 8 taxa

df = pd.read_csv("./data/kmeans_8_diff_topo_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/kmeans_8_diff_topo_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
diff_kmeans_1000 = pd.DataFrame(accuracy)

plt.figure(figsize=(12,12))
plt.title('8 taxa with K-means')
plot = sns.heatmap(diff_kmeans_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_prob_8_topo_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/GMM_prob_8_topo_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
diff_prob_1000 = pd.DataFrame(accuracy)

plt.figure(figsize=(12,12))
plt.title('8 taxa with GMM prob')
plot = sns.heatmap(diff_prob_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='y', rotation=0)

df = pd.read_csv("./data/GMM_llpg_8_topo_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/GMM_llpg_8_topo_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
diff_llpg_1000 = pd.DataFrame(accuracy)

plt.figure(figsize=(12,12))
plt.title('8 taxa with GMM llpg')
plot = sns.heatmap(diff_llpg_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='y', rotation=0)
