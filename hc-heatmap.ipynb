# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math   
from itertools import combinations

# %%
trees = ["(((4,3),2),1)","(((4,2),3),1)","(((3,2),4),1)","(((4,3),1),2)","(((4,1),3),2)",
         "(((1,3),4),2)","(((1,2),4),3)","(((4,2),1),3)","(((4,1),2),3)","(((2,1),3),4)",
         "(((1,3),2),4)","(((3,2),1),4)","((4,3),(2,1))","((4,1),(2,3))","((4,2),(3,1))"]

unrooted = ["1: 12|34","2: 13|24","3: 14|23","4: 12|34","5: 14|23",
            "6: 13|24","7: 12|34","8: 13|24","9: 14|23","10: 12|34",
            "11: 13|24","12: 14|23","13: 12|34","14: 14|23","15: 13|24"]
newIdx = ["1: 12|34", "4: 12|34", "7: 12|34", "10: 12|34", "13: 12|34", 
          "2: 13|24", "6: 13|24", "8: 13|24", "11: 13|24", "15: 13|24", 
          "3: 14|23", "5: 14|23", "9: 14|23", "12: 14|23", "14: 14|23"]

# %%
df = pd.read_csv("./data/hc/4/hc_4_diff_topo_50_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/4/hc_4_diff_topo_50_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_50 = pd.DataFrame(accuracy)
hc_50.columns = trees
hc_50.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('50 different topologies HC')
plot = sns.heatmap(hc_50, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

result = hc_50.to_numpy()
all_comb = list(combinations(range(0,15),2))
good_75 = []

for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    
    if result[i,j] >= 0.75:
        good_75.append(pair)
        
matrix_75 = [[0 for x in range(15)] for y in range(15)] 

for pair in good_75:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix_75[i][j] += 1
    matrix_75[j][i] += 1
    
matrix_75 = pd.DataFrame(matrix_75)
matrix_75.columns = unrooted
matrix_75.index = unrooted
matrix_75 = matrix_75.reindex(newIdx)
matrix_75 = matrix_75.reindex(columns = newIdx)

plt.figure(figsize=(10,10), dpi=80)
plt.title('Good performance = 0.75')
plot = sns.heatmap(matrix_75, annot=True, cmap="crest", cbar = False)
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/hc/4/hc_4_diff_topo_100_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/4/hc_4_diff_topo_100_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_100 = pd.DataFrame(accuracy)
hc_100.columns = trees
hc_100.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('100 different topologies HC')
plot = sns.heatmap(hc_100, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

result = hc_100.to_numpy()
all_comb = list(combinations(range(0,15),2))
good_75 = []

for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    
    if result[i,j] >= 0.75:
        good_75.append(pair)
        
matrix_75 = [[0 for x in range(15)] for y in range(15)] 

for pair in good_75:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix_75[i][j] += 1
    matrix_75[j][i] += 1
    
matrix_75 = pd.DataFrame(matrix_75)
matrix_75.columns = unrooted
matrix_75.index = unrooted
matrix_75 = matrix_75.reindex(newIdx)
matrix_75 = matrix_75.reindex(columns = newIdx)

plt.figure(figsize=(10,10), dpi=80)
plt.title('Good performance = 0.75')
plot = sns.heatmap(matrix_75, annot=True, cmap="crest", cbar = False)
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/hc/4/hc_4_diff_topo_500_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/4/hc_4_diff_topo_500_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_500 = pd.DataFrame(accuracy)
hc_500.columns = trees	
hc_500.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('500 different topologies HC')
plot = sns.heatmap(hc_500, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

result = hc_500.to_numpy()
all_comb = list(combinations(range(0,15),2))
good_75 = []

for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    
    if result[i,j] >= 0.75:
        good_75.append(pair)
        
matrix_75 = [[0 for x in range(15)] for y in range(15)] 

for pair in good_75:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix_75[i][j] += 1
    matrix_75[j][i] += 1
    
matrix_75 = pd.DataFrame(matrix_75)
matrix_75.columns = unrooted
matrix_75.index = unrooted
matrix_75 = matrix_75.reindex(newIdx)
matrix_75 = matrix_75.reindex(columns = newIdx)

plt.figure(figsize=(10,10), dpi=80)
plt.title('Good performance = 0.75')
plot = sns.heatmap(matrix_75, annot=True, cmap="crest", cbar = False)
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/hc/4/hc_4_diff_topo_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/4/hc_4_diff_topo_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_1000 = pd.DataFrame(accuracy)
hc_1000.columns = trees	
hc_1000.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('1000 different topologies HC')
plot = sns.heatmap(hc_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

result = hc_1000.to_numpy()
all_comb = list(combinations(range(0,15),2))
good_75 = []

for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    
    if result[i,j] >= 0.75:
        good_75.append(pair)
        
matrix_75 = [[0 for x in range(15)] for y in range(15)] 

for pair in good_75:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix_75[i][j] += 1
    matrix_75[j][i] += 1
    
matrix_75 = pd.DataFrame(matrix_75)
matrix_75.columns = unrooted
matrix_75.index = unrooted
matrix_75 = matrix_75.reindex(newIdx)
matrix_75 = matrix_75.reindex(columns = newIdx)

plt.figure(figsize=(10,10), dpi=80)
plt.title('Good performance = 0.75')
plot = sns.heatmap(matrix_75, annot=True, cmap="crest", cbar = False)
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/hc/4/hc_4_diff_topo_5000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/4/hc_4_diff_topo_5000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_5000 = pd.DataFrame(accuracy)
hc_5000.columns = trees	
hc_5000.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('5000 different topologies HC')
plot = sns.heatmap(hc_5000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

result = hc_5000.to_numpy()
all_comb = list(combinations(range(0,15),2))
good_75 = []

for comb in all_comb:
    i = comb[0]
    j = comb[1]
    pair = (i+1,j+1)
    
    if result[i,j] >= 0.75:
        good_75.append(pair)
        
matrix_75 = [[0 for x in range(15)] for y in range(15)] 

for pair in good_75:
    i = pair[0] - 1
    j = pair[1] - 1
    matrix_75[i][j] += 1
    matrix_75[j][i] += 1
    
matrix_75 = pd.DataFrame(matrix_75)
matrix_75.columns = unrooted
matrix_75.index = unrooted
matrix_75 = matrix_75.reindex(newIdx)
matrix_75 = matrix_75.reindex(columns = newIdx)

plt.figure(figsize=(10,10), dpi=80)
plt.title('Good performance = 0.75')
plot = sns.heatmap(matrix_75, annot=True, cmap="crest", cbar = False)
plot.tick_params(axis='x', rotation=45)
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/hc/8/hc_8_diff_topo_50_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/8/hc_8_diff_topo_50_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_50 = pd.DataFrame(accuracy)
hc_50.columns = trees
hc_50.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('50 different topologies HC')
plot = sns.heatmap(hc_50, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)

# %%
df = pd.read_csv("./data/hc/8/hc_8_diff_topo_100_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/8/hc_8_diff_topo_100_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_100 = pd.DataFrame(accuracy)
hc_100.columns = trees
hc_100.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('100 different topologies HC')
plot = sns.heatmap(hc_100, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)

# %%
df = pd.read_csv("./data/hc/8/hc_8_diff_topo_500_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/8/hc_8_diff_topo_500_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_500 = pd.DataFrame(accuracy)
hc_500.columns = trees
hc_500.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('500 different topologies HC')
plot = sns.heatmap(hc_500, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)

# %%
df = pd.read_csv("./data/hc/8/hc_8_diff_topo_1000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/8/hc_8_diff_topo_1000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_1000 = pd.DataFrame(accuracy)
hc_1000.columns = trees
hc_1000.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('1000 different topologies HC')
plot = sns.heatmap(hc_1000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)

# %%
df = pd.read_csv("./data/hc/8/hc_8_diff_topo_5000_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/hc/8/hc_8_diff_topo_5000_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
hc_5000 = pd.DataFrame(accuracy)
hc_5000.columns = trees
hc_5000.index = trees

plt.figure(figsize=(10,10), dpi=80)
plt.title('5000 different topologies HC')
plot = sns.heatmap(hc_5000, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='x', rotation=45)

# %%
df = pd.read_csv("./data/nni/result/nni_reuslt_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/nni/result/nni_reuslt_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
nni = pd.DataFrame(accuracy)

plt.figure(figsize=(10,10), dpi=80)
plt.title('NNI check for 8-taxon trees')
plot = sns.heatmap(nni, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='y', rotation=0)

# %%
df = pd.read_csv("./data/nni/result/nni_16_reuslt_1.csv")
accuracy = df.values
for i in range(99):
    path = "./data/nni/result/nni_16_reuslt_" + str(i + 2) + ".csv"
    df = pd.read_csv(path)
    accuracy += df.values

accuracy /= 100
nni = pd.DataFrame(accuracy)

plt.figure(figsize=(10,10), dpi=80)
plt.title('NNI check for 16-taxon trees')
plot = sns.heatmap(nni, annot=True, cmap="crest",vmin = 0.5, vmax = 1);
plot.xaxis.tick_top()
plot.tick_params(axis='y', rotation=0)
